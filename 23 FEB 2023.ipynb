# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Scikit-learn Datasets

# %%
from sklearn.datasets import fetch_california_housing

# %% [markdown]
#    # Load data (will download the data if its the first time loading

# %%
housing = fetch_california_housing(as_frame=True)

# %% [markdown]
# ## Create a dataframe

# %%
df = housing['data'].join(housing['target'])
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %% [markdown]
# # task ; load the dataset to eda

# %% [markdown]
# ### line charts

# %%
df.Population.plot.hist(figsize=(6,3), cmap = 'RdYlBu');

# %% [markdown]
# ### box plot

# %%
df.HouseAge.plot.box(figsize = (4,3), cmap = ('gist_earth'));

# %%
df.Latitude.plot.box(figsize=(4,3), cmap = 'twilight');

# %% [markdown]
# ### Subplots

# %%
df.plot.box(figsize = (22,4), subplots = True);

# %%
df.plot.hist(figsize=(6,8), subplots = True);

# %% [markdown]
# ### Line charts

# %%
df.sort_values(by = 'Population').plot.line('Population','HouseAge', figsize=(6,3), cmap = 'brg');

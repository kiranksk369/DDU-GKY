# %% [markdown]
# # creating a dataframe

# %%
import pandas as pd
import numpy as np
import warnings
warnings filterwarnings ("ignore")

# %%
cars={"brand":["bmw","benz"],
     "model":[1986,1983]}

df=pd.DataFrame(cars)
df.head()
# Out:
#   brand  model
# 0   bmw   1986
# 1  benz   1983

# %% [markdown]
# # task

# %%
students={
    "NAME" : ["abhhimanyu","akshay","alen tom","anand","anzal","arun","aswin","dhavood","haripriya","indrajith","jishnu","jishnuraj","jopika","keerthi","kiran","lubina","mancy","merlin","safeer","siraj","nandu","najmi","nida","rahul","ramshad","sanika","sanoy","shammas","smijith","sneha","soorya","swathi","vidhya","vishnu"],
    "PYTHON" : [25,24,25,24,25,25,25,24,24,24,24,25,25,23,24,25,24,24,25,24,24,24,0,25,25,25,25,25,24,24,24,22,24,25,23,24],
    "STATISTICS" :  [15,15,18,16,19,15,13,16,17,13,15,15,13,16,20,16,16,16,15,19,22,0,13,15,16,19,17,15,17,13,13,16,16,17,17],
     'TOTAL':[45,39,40,42,43,41,44,39,37,40,41,38,40,38,37,41,44,40,41,40,39,43,0,38,40,41,44,42,39,41,37,35,40,41,40]
}

sd=pd.DataFrame(students)
print(sd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11444\2255411343.py in <module>
#       6 }
#       7
# ----> 8 sd=pd.DataFrame(students)
#       9 print(sd)
#      10
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
students={
    'NAME':["abhimanyu","ajith","akshay","alentom","anand","ansal","arun","aswin","dawood","haripriya","indrajith","jishnu","jishnuraj","jopika","keerthi","kiran","lubna","mancy","merlin","safeer","siraj","nandakrishnan","najmi","nida","rahul","ramshad","sanika","sanoy","shammas","smijith","sneha","soorya","swathi","vidya","vishnu"],
    'PYTHON':[24,25,24,25,25,25,24,24,24,24,25,25,23,24,25,24,24,25,24,24,24,0,25,25,25,25,25,24,24,24,22,24,25,23,24],
    'STATISTICS':[15,15,18,16,19,15,13,16,17,13,15,15,13,16,20,16,20,16,15,19,22,0,13,15,16,19,17,15,17,13,13,16,16,17,17],
    'TOTAL':[45,39,40,42,43,41,44,39,37,40,41,38,40,38,37,41,44,40,41,40,39,43,0,38,40,41,44,42,39,41,37,35,40,41,40]
}
sd=pd.DataFrame(students)
print(sd)
# Out:
#              NAME  PYTHON  STATISTICS  TOTAL
# 0       abhimanyu      24          15     45
# 1           ajith      25          15     39
# 2          akshay      24          18     40
# 3         alentom      25          16     42
# 4           anand      25          19     43
# 5           ansal      25          15     41
# 6            arun      24          13     44
# 7           aswin      24          16     39
# 8          dawood      24          17     37
# 9       haripriya      24          13     40
# 10      indrajith      25          15     41
# 11         jishnu      25          15     38
# 12      jishnuraj      23          13     40
# 13         jopika      24          16     38
# 14        keerthi      25          20     37
# 15          kiran      24          16     41
# 16          lubna      24          20     44
# 17          mancy      25          16     40
# 18         merlin      24          15     41
# 19         safeer      24          19     40
# ...

# %%
sd[sd["TOTAL"]>40]
# Out:
#              NAME  PYTHON  STATISTICS  TOTAL
# 0       abhimanyu      24          15     45
# 3         alentom      25          16     42
# 4           anand      25          19     43
# 5           ansal      25          15     41
# 6            arun      24          13     44
# 10      indrajith      25          15     41
# 15          kiran      24          16     41
# 16          lubna      24          20     44
# 18         merlin      24          15     41
# 21  nandakrishnan       0           0     43
# 25        ramshad      25          19     41
# 26         sanika      25          17     44
# 27          sanoy      24          15     42
# 29        smijith      24          13     41
# 33          vidya      23          17     41

# %%
sd["NAME"][sd["PYTHON"]<25]
# Out:
# 0         abhimanyu
# 2            akshay
# 6              arun
# 7             aswin
# 8            dawood
# 9         haripriya
# 12        jishnuraj
# 13           jopika
# 15            kiran
# 16            lubna
# 18           merlin
# 19           safeer
# 20            siraj
# 21    nandakrishnan
# 27            sanoy
# 28          shammas
# 29          smijith
# 30            sneha
# 31           soorya
# 33            vidya
# 34           vishnu
# Name: NAME, dtype: object

# %%
#best student
best=sd["TOTAL"].max()
print(best)
# Out:
# 45

# %%
sd.loc[7]
# Out:
# NAME          aswin
# PYTHON           24
# STATISTICS       16
# TOTAL            39
# Name: 7, dtype: object

# %%
sd.set_index("NAME")
# Out:
#                PYTHON  STATISTICS  TOTAL
# NAME
# abhimanyu          24          15     45
# ajith              25          15     39
# akshay             24          18     40
# alentom            25          16     42
# anand              25          19     43
# ansal              25          15     41
# arun               24          13     44
# aswin              24          16     39
# dawood             24          17     37
# haripriya          24          13     40
# indrajith          25          15     41
# jishnu             25          15     38
# jishnuraj          23          13     40
# jopika             24          16     38
# keerthi            25          20     37
# kiran              24          16     41
# lubna              24          20     44
# mancy              25          16     40
# merlin             24          15     41
# safeer             24          19     40
# siraj              24          22     39
# nandakrishnan       0           0     43
# ...

# %%
std=sd["TOTAL"].mean()
print(std)
# Out:
# 39.142857142857146

# %%
abc=sd["TOTAL"].std()
print(abc)
# Out:
# 7.170785735693605
